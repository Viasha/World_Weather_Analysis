# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 746

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data2 = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_conditions = city_weather["weather"][0]["description"]
        #parsing array reference: https://devqa.io/python-parse-json/
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data2.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                           "Current Description": city_conditions,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hualahuises
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | poum
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | namwala
# Processing Record 11 of Set 1 | atar
# Processing Record 12 of Set 1 | nueva londres
# Processing Record 13 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | demyansk
# Processing Record 18 of Set 1 | klaksvik
# Processing Record 19 of Set 1 | la ronge
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | teya
# Processing Record 24 of Set 1 | maniitsoq
# Processing Record 25 of Set 1 | yerbogachen
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | lakes entrance
# Processing Record 29 of Set 1 | beidao
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | tabou
# Processing Record 32 of Set 1 | tilichiki
# Processing Record 33 of Set 1 | anadyr
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | kumba
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | cockburn town
# Processing Record 38 of Set 1 | tomatlan
# Processing Record 39 of Set 1 | kota bahru
# Processing Record 40 of Set 1 | liverpool
# Processing Record 41 of Set 1 | auki
# Processing Record 42 of Set 1 | ashland
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | qasigiannguit
# Processing Record 46 of Set 1 | vaini
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | sobolevo
# Processing Record 50 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 2 | yulara
# Processing Record 2 of Set 2 | vredendal
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | pevek
# Processing Record 5 of Set 2 | ilulissat
# Processing Record 6 of Set 2 | lebu
# Processing Record 7 of Set 2 | kalaleh
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 2 | bahia de caraquez
# Processing Record 11 of Set 2 | tessalit
# Processing Record 12 of Set 2 | mitchell
# Processing Record 13 of Set 2 | marzuq
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | umm lajj
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | makakilo city
# Processing Record 19 of Set 2 | aswan
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | richards bay
# Processing Record 22 of Set 2 | carahue
# Processing Record 23 of Set 2 | roald
# Processing Record 24 of Set 2 | kirakira
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 2 | caravelas
# Processing Record 28 of Set 2 | bredasdorp
# Processing Record 29 of Set 2 | norrkoping
# Processing Record 30 of Set 2 | mandalgovi
# Processing Record 31 of Set 2 | albany
# Processing Record 32 of Set 2 | bambanglipuro
# Processing Record 33 of Set 2 | beinamar
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | new norfolk
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | nikel
# Processing Record 39 of Set 2 | eureka
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | koungou
# Processing Record 43 of Set 2 | rongcheng
# Processing Record 44 of Set 2 | vardo
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | krutinka
# Processing Record 49 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 2 | oktyabrskiy
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | bonavista
# Processing Record 3 of Set 3 | brae
# Processing Record 4 of Set 3 | chokurdakh
# Processing Record 5 of Set 3 | kalabo
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | kununurra
# Processing Record 8 of Set 3 | mana
# Processing Record 9 of Set 3 | coihaique
# Processing Record 10 of Set 3 | lishui
# Processing Record 11 of Set 3 | lodja
# Processing Record 12 of Set 3 | bani walid
# Processing Record 13 of Set 3 | namatanai
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | bourail
# Processing Record 16 of Set 3 | san cristobal
# Processing Record 17 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | saint george
# Processing Record 20 of Set 3 | walvis bay
# Processing Record 21 of Set 3 | maraa
# Processing Record 22 of Set 3 | colgong
# Processing Record 23 of Set 3 | kruisfontein
# Processing Record 24 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | georgetown
# Processing Record 29 of Set 3 | necochea
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | uyo
# Processing Record 33 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 3 | hauterive
# Processing Record 35 of Set 3 | thessalon
# Processing Record 36 of Set 3 | lida
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | primo tapia
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | yaguajay
# Processing Record 41 of Set 3 | kawalu
# Processing Record 42 of Set 3 | yantal
# Processing Record 43 of Set 3 | kimberley
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | paamiut
# Processing Record 46 of Set 3 | jizan
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | leningradskiy
# Processing Record 49 of Set 3 | bereda
# Processing Record 50 of Set 3 | nanortalik
# Processing Record 1 of Set 4 | avera
# Processing Record 2 of Set 4 | huicungo
# Processing Record 3 of Set 4 | shitanjing
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | pizarro
# Processing Record 7 of Set 4 | minsk
# Processing Record 8 of Set 4 | bara
# Processing Record 9 of Set 4 | uige
# Processing Record 10 of Set 4 | volnovakha
# Processing Record 11 of Set 4 | monrovia
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | prince rupert
# Processing Record 14 of Set 4 | sibolga
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | pajarito
# Processing Record 17 of Set 4 | susanville
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | yar-sale
# Processing Record 21 of Set 4 | atuona
# Processing Record 22 of Set 4 | carnarvon
# Processing Record 23 of Set 4 | sao cristovao
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | nargana
# Processing Record 26 of Set 4 | nerchinskiy zavod
# Processing Record 27 of Set 4 | rypin
# Processing Record 28 of Set 4 | airai
# Processing Record 29 of Set 4 | hellvik
# Processing Record 30 of Set 4 | tobol
# Processing Record 31 of Set 4 | eyl
# Processing Record 32 of Set 4 | santa fe
# Processing Record 33 of Set 4 | houlung
# City not found. Skipping...
# Processing Record 34 of Set 4 | beringovskiy
# Processing Record 35 of Set 4 | santa lucia
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | liliongan
# Processing Record 38 of Set 4 | fort nelson
# Processing Record 39 of Set 4 | darhan
# Processing Record 40 of Set 4 | sao joao da barra
# Processing Record 41 of Set 4 | coolum beach
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | alice springs
# Processing Record 44 of Set 4 | spas-demensk
# Processing Record 45 of Set 4 | tifton
# Processing Record 46 of Set 4 | butaritari
# Processing Record 47 of Set 4 | atka
# City not found. Skipping...
# Processing Record 48 of Set 4 | ust-maya
# Processing Record 49 of Set 4 | totness
# Processing Record 50 of Set 4 | bambous virieux
# Processing Record 1 of Set 5 | solnechnyy
# Processing Record 2 of Set 5 | swan river
# Processing Record 3 of Set 5 | margate
# Processing Record 4 of Set 5 | jumla
# Processing Record 5 of Set 5 | strezhevoy
# Processing Record 6 of Set 5 | gigmoto
# Processing Record 7 of Set 5 | burnie
# Processing Record 8 of Set 5 | half moon bay
# Processing Record 9 of Set 5 | shar
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | lagoa
# Processing Record 12 of Set 5 | adre
# Processing Record 13 of Set 5 | yei
# Processing Record 14 of Set 5 | yurga
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | codrington
# Processing Record 17 of Set 5 | papasquiaro
# City not found. Skipping...
# Processing Record 18 of Set 5 | thaba-tseka
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | alexandria
# Processing Record 21 of Set 5 | honiara
# Processing Record 22 of Set 5 | atasu
# Processing Record 23 of Set 5 | takoradi
# Processing Record 24 of Set 5 | udachnyy
# Processing Record 25 of Set 5 | smiths falls
# Processing Record 26 of Set 5 | uyuni
# Processing Record 27 of Set 5 | chara
# Processing Record 28 of Set 5 | bethel
# Processing Record 29 of Set 5 | havoysund
# Processing Record 30 of Set 5 | tura
# Processing Record 31 of Set 5 | victoria
# Processing Record 32 of Set 5 | komsomolskiy
# Processing Record 33 of Set 5 | kloulklubed
# Processing Record 34 of Set 5 | buala
# Processing Record 35 of Set 5 | provideniya
# Processing Record 36 of Set 5 | pochutla
# Processing Record 37 of Set 5 | narasannapeta
# Processing Record 38 of Set 5 | saint-pierre
# Processing Record 39 of Set 5 | ugoofaaru
# Processing Record 40 of Set 5 | sept-iles
# Processing Record 41 of Set 5 | vestmanna
# Processing Record 42 of Set 5 | jieshi
# Processing Record 43 of Set 5 | huangchuan
# Processing Record 44 of Set 5 | nouakchott
# Processing Record 45 of Set 5 | mayo
# Processing Record 46 of Set 5 | san patricio
# Processing Record 47 of Set 5 | kutum
# Processing Record 48 of Set 5 | diego de almagro
# Processing Record 49 of Set 5 | erenhot
# Processing Record 50 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 6 | yumen
# Processing Record 2 of Set 6 | luanda
# Processing Record 3 of Set 6 | mitsamiouli
# Processing Record 4 of Set 6 | coos bay
# Processing Record 5 of Set 6 | kyaikto
# Processing Record 6 of Set 6 | petatlan
# Processing Record 7 of Set 6 | glace bay
# Processing Record 8 of Set 6 | kushima
# Processing Record 9 of Set 6 | jiuquan
# Processing Record 10 of Set 6 | ippy
# Processing Record 11 of Set 6 | tautira
# Processing Record 12 of Set 6 | lata
# Processing Record 13 of Set 6 | hualmay
# Processing Record 14 of Set 6 | cabedelo
# Processing Record 15 of Set 6 | stornoway
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | aranos
# Processing Record 18 of Set 6 | uvira
# Processing Record 19 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | ballybofey
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | castro
# Processing Record 24 of Set 6 | sabang
# Processing Record 25 of Set 6 | puerto escondido
# Processing Record 26 of Set 6 | lampang
# Processing Record 27 of Set 6 | okhotsk
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | zilair
# Processing Record 30 of Set 6 | pangani
# Processing Record 31 of Set 6 | kieta
# Processing Record 32 of Set 6 | hovd
# Processing Record 33 of Set 6 | beisfjord
# Processing Record 34 of Set 6 | dunedin
# Processing Record 35 of Set 6 | goderich
# Processing Record 36 of Set 6 | nouadhibou
# Processing Record 37 of Set 6 | acapulco
# Processing Record 38 of Set 6 | keningau
# Processing Record 39 of Set 6 | iqaluit
# Processing Record 40 of Set 6 | sechura
# Processing Record 41 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 6 | posevnaya
# Processing Record 43 of Set 6 | trinidad
# Processing Record 44 of Set 6 | japura
# Processing Record 45 of Set 6 | eldoret
# Processing Record 46 of Set 6 | kastamonu
# Processing Record 47 of Set 6 | bilibino
# Processing Record 48 of Set 6 | tanete
# Processing Record 49 of Set 6 | pitimbu
# Processing Record 50 of Set 6 | talnakh
# Processing Record 1 of Set 7 | kunigal
# Processing Record 2 of Set 7 | santa cruz
# Processing Record 3 of Set 7 | ranot
# Processing Record 4 of Set 7 | svetlogorsk
# Processing Record 5 of Set 7 | tacuarembo
# Processing Record 6 of Set 7 | sitka
# Processing Record 7 of Set 7 | ust-kuyga
# Processing Record 8 of Set 7 | bure
# Processing Record 9 of Set 7 | vanavara
# Processing Record 10 of Set 7 | kysyl-syr
# Processing Record 11 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 7 | manavalakurichi
# Processing Record 13 of Set 7 | visnes
# Processing Record 14 of Set 7 | grindavik
# Processing Record 15 of Set 7 | nanchong
# Processing Record 16 of Set 7 | shchelyayur
# City not found. Skipping...
# Processing Record 17 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 7 | aksu
# Processing Record 19 of Set 7 | san
# Processing Record 20 of Set 7 | yeppoon
# Processing Record 21 of Set 7 | adrar
# Processing Record 22 of Set 7 | ilo
# Processing Record 23 of Set 7 | jatai
# Processing Record 24 of Set 7 | kavaratti
# Processing Record 25 of Set 7 | mandera
# Processing Record 26 of Set 7 | praia da vitoria
# Processing Record 27 of Set 7 | itacoatiara
# Processing Record 28 of Set 7 | comodoro rivadavia
# Processing Record 29 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | bowen
# Processing Record 32 of Set 7 | gwadar
# Processing Record 33 of Set 7 | ostrovnoy
# Processing Record 34 of Set 7 | ijuin
# Processing Record 35 of Set 7 | castlegar
# Processing Record 36 of Set 7 | vladyslavivka
# Processing Record 37 of Set 7 | inta
# Processing Record 38 of Set 7 | jyvaskyla
# Processing Record 39 of Set 7 | yambio
# Processing Record 40 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 7 | smithers
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | pilar
# Processing Record 44 of Set 7 | nur
# Processing Record 45 of Set 7 | pinar del rio
# Processing Record 46 of Set 7 | nokia
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | quimperle
# Processing Record 49 of Set 7 | kargopol
# Processing Record 50 of Set 7 | north bend
# Processing Record 1 of Set 8 | rio blanco
# Processing Record 2 of Set 8 | takab
# Processing Record 3 of Set 8 | borba
# Processing Record 4 of Set 8 | kaeo
# Processing Record 5 of Set 8 | helong
# Processing Record 6 of Set 8 | agrate brianza
# Processing Record 7 of Set 8 | san salvador
# Processing Record 8 of Set 8 | prado
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | phonhong
# Processing Record 11 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 8 | moose factory
# Processing Record 13 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 8 | winnemucca
# Processing Record 15 of Set 8 | esperance
# Processing Record 16 of Set 8 | nome
# Processing Record 17 of Set 8 | huilong
# Processing Record 18 of Set 8 | dubbo
# Processing Record 19 of Set 8 | ginir
# Processing Record 20 of Set 8 | acheng
# Processing Record 21 of Set 8 | darnah
# Processing Record 22 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 8 | fuyu
# Processing Record 24 of Set 8 | ajaccio
# Processing Record 25 of Set 8 | matagami
# Processing Record 26 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 8 | hailar
# Processing Record 28 of Set 8 | martigues
# Processing Record 29 of Set 8 | luganville
# Processing Record 30 of Set 8 | chegdomyn
# Processing Record 31 of Set 8 | meadow lake
# Processing Record 32 of Set 8 | lulea
# Processing Record 33 of Set 8 | port hawkesbury
# Processing Record 34 of Set 8 | harur
# Processing Record 35 of Set 8 | salalah
# Processing Record 36 of Set 8 | aksarka
# Processing Record 37 of Set 8 | mackenzie
# Processing Record 38 of Set 8 | raton
# Processing Record 39 of Set 8 | sisimiut
# Processing Record 40 of Set 8 | shawinigan
# Processing Record 41 of Set 8 | te anau
# Processing Record 42 of Set 8 | saint-augustin
# Processing Record 43 of Set 8 | whitianga
# Processing Record 44 of Set 8 | whitehorse
# Processing Record 45 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 8 | othaya
# Processing Record 47 of Set 8 | kodinsk
# Processing Record 48 of Set 8 | yanam
# Processing Record 49 of Set 8 | shieli
# Processing Record 50 of Set 8 | nuuk
# Processing Record 1 of Set 9 | coahuayana
# Processing Record 2 of Set 9 | boone
# Processing Record 3 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 9 | capivari
# Processing Record 5 of Set 9 | lompoc
# Processing Record 6 of Set 9 | kaihua
# Processing Record 7 of Set 9 | pisco
# Processing Record 8 of Set 9 | sanmenxia
# Processing Record 9 of Set 9 | salinas
# Processing Record 10 of Set 9 | bagotville
# Processing Record 11 of Set 9 | longyearbyen
# Processing Record 12 of Set 9 | casablanca
# Processing Record 13 of Set 9 | touros
# Processing Record 14 of Set 9 | belmonte
# Processing Record 15 of Set 9 | lavrentiya
# Processing Record 16 of Set 9 | rawson
# Processing Record 17 of Set 9 | blackwater
# Processing Record 18 of Set 9 | malkara
# Processing Record 19 of Set 9 | guider
# Processing Record 20 of Set 9 | manzil salim
# Processing Record 21 of Set 9 | locri
# Processing Record 22 of Set 9 | oranjestad
# Processing Record 23 of Set 9 | roshchino
# Processing Record 24 of Set 9 | ozernovskiy
# Processing Record 25 of Set 9 | mezen
# Processing Record 26 of Set 9 | kamiiso
# Processing Record 27 of Set 9 | radishchevo
# Processing Record 28 of Set 9 | ravar
# Processing Record 29 of Set 9 | mubi
# Processing Record 30 of Set 9 | shimoda
# Processing Record 31 of Set 9 | sokolo
# Processing Record 32 of Set 9 | sharkan
# Processing Record 33 of Set 9 | los llanos de aridane
# Processing Record 34 of Set 9 | mombasa
# Processing Record 35 of Set 9 | san pedro
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | maceio
# Processing Record 38 of Set 9 | portland
# Processing Record 39 of Set 9 | saldanha
# Processing Record 40 of Set 9 | roebourne
# Processing Record 41 of Set 9 | sosva
# Processing Record 42 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 9 | nantucket
# Processing Record 44 of Set 9 | dalvik
# Processing Record 45 of Set 9 | biratnagar
# Processing Record 46 of Set 9 | berlevag
# Processing Record 47 of Set 9 | toktogul
# Processing Record 48 of Set 9 | dzilam gonzalez
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 50 of Set 9 | buchanan
# Processing Record 1 of Set 10 | winslow
# Processing Record 2 of Set 10 | northam
# Processing Record 3 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 10 | asau
# Processing Record 5 of Set 10 | mayor pablo lagerenza
# Processing Record 6 of Set 10 | kathu
# Processing Record 7 of Set 10 | waipawa
# Processing Record 8 of Set 10 | sydney
# Processing Record 9 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 10 of Set 10 | verkhnevilyuysk
# Processing Record 11 of Set 10 | suamico
# Processing Record 12 of Set 10 | sao jose da coroa grande
# Processing Record 13 of Set 10 | sola
# Processing Record 14 of Set 10 | nyurba
# Processing Record 15 of Set 10 | lethem
# Processing Record 16 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 10 | flin flon
# Processing Record 18 of Set 10 | zafarwal
# Processing Record 19 of Set 10 | savannakhet
# Processing Record 20 of Set 10 | laguna
# Processing Record 21 of Set 10 | hearst
# Processing Record 22 of Set 10 | pimentel
# Processing Record 23 of Set 10 | saint anthony
# Processing Record 24 of Set 10 | fairbanks
# Processing Record 25 of Set 10 | bandar-e anzali
# Processing Record 26 of Set 10 | helena
# Processing Record 27 of Set 10 | najran
# Processing Record 28 of Set 10 | rawah
# Processing Record 29 of Set 10 | juneau
# Processing Record 30 of Set 10 | ascension
# Processing Record 31 of Set 10 | tete
# Processing Record 32 of Set 10 | kuala terengganu
# Processing Record 33 of Set 10 | morganton
# Processing Record 34 of Set 10 | geraldton
# Processing Record 35 of Set 10 | the valley
# Processing Record 36 of Set 10 | lumphat
# Processing Record 37 of Set 10 | presque isle
# Processing Record 38 of Set 10 | biak
# Processing Record 39 of Set 10 | calama
# Processing Record 40 of Set 10 | westport
# Processing Record 41 of Set 10 | murree
# Processing Record 42 of Set 10 | cherskiy
# Processing Record 43 of Set 10 | aguimes
# Processing Record 44 of Set 10 | nova olimpia
# Processing Record 45 of Set 10 | lorengau
# Processing Record 46 of Set 10 | chugunash
# City not found. Skipping...
# Processing Record 47 of Set 10 | sayyan
# Processing Record 48 of Set 10 | ibra
# Processing Record 49 of Set 10 | sar-e pul
# Processing Record 50 of Set 10 | codo
# Processing Record 1 of Set 11 | laguna de perlas
# Processing Record 2 of Set 11 | valdivia
# Processing Record 3 of Set 11 | clyde river
# Processing Record 4 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 5 of Set 11 | dauriya
# Processing Record 6 of Set 11 | balkhash
# Processing Record 7 of Set 11 | ponta delgada
# Processing Record 8 of Set 11 | la primavera
# Processing Record 9 of Set 11 | kapoeta
# Processing Record 10 of Set 11 | piacabucu
# Processing Record 11 of Set 11 | bathsheba
# Processing Record 12 of Set 11 | uarini
# Processing Record 13 of Set 11 | ambilobe
# Processing Record 14 of Set 11 | padang
# Processing Record 15 of Set 11 | priladozhskiy
# Processing Record 16 of Set 11 | kahului
# Processing Record 17 of Set 11 | new baltimore
# Processing Record 18 of Set 11 | omboue
# Processing Record 19 of Set 11 | bom jesus da lapa
# Processing Record 20 of Set 11 | lambarene
# Processing Record 21 of Set 11 | mathathane
# Processing Record 22 of Set 11 | henties bay
# Processing Record 23 of Set 11 | chuguyevka
# Processing Record 24 of Set 11 | lavumisa
# Processing Record 25 of Set 11 | encruzilhada
# Processing Record 26 of Set 11 | morondava
# Processing Record 27 of Set 11 | collie
# Processing Record 28 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 29 of Set 11 | carballo
# Processing Record 30 of Set 11 | huarmey
# Processing Record 31 of Set 11 | mogadishu
# Processing Record 32 of Set 11 | xining
# Processing Record 33 of Set 11 | gizo
# Processing Record 34 of Set 11 | tabory
# Processing Record 35 of Set 11 | estelle
# Processing Record 36 of Set 11 | solyanka
# Processing Record 37 of Set 11 | zyryanka
# Processing Record 38 of Set 11 | chadiza
# Processing Record 39 of Set 11 | ulaanbaatar
# Processing Record 40 of Set 11 | russell
# Processing Record 41 of Set 11 | port hardy
# Processing Record 42 of Set 11 | zvishavane
# Processing Record 43 of Set 11 | ancud
# Processing Record 44 of Set 11 | stykkisholmur
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | palafrugell
# Processing Record 47 of Set 11 | bilma
# Processing Record 48 of Set 11 | ahuimanu
# Processing Record 49 of Set 11 | tigil
# Processing Record 50 of Set 11 | makat
# Processing Record 1 of Set 12 | paita
# Processing Record 2 of Set 12 | algiers
# Processing Record 3 of Set 12 | sur
# Processing Record 4 of Set 12 | ahipara
# Processing Record 5 of Set 12 | birao
# Processing Record 6 of Set 12 | kalamia
# Processing Record 7 of Set 12 | angoche
# Processing Record 8 of Set 12 | carutapera
# Processing Record 9 of Set 12 | ilorin
# Processing Record 10 of Set 12 | naranjos
# Processing Record 11 of Set 12 | ust-kulom
# Processing Record 12 of Set 12 | santarem
# Processing Record 13 of Set 12 | chapais
# Processing Record 14 of Set 12 | pacific grove
# Processing Record 15 of Set 12 | nipawin
# Processing Record 16 of Set 12 | aklavik
# Processing Record 17 of Set 12 | yvetot
# Processing Record 18 of Set 12 | poltavka
# Processing Record 19 of Set 12 | casa grande
# Processing Record 20 of Set 12 | lumut
# Processing Record 21 of Set 12 | suffolk
# Processing Record 22 of Set 12 | mahanje
# Processing Record 23 of Set 12 | tuatapere
# Processing Record 24 of Set 12 | abdulino
# Processing Record 25 of Set 12 | kyren
# Processing Record 26 of Set 12 | kargasok
# Processing Record 27 of Set 12 | coffs harbour
# Processing Record 28 of Set 12 | kikwit
# Processing Record 29 of Set 12 | nueva guinea
# Processing Record 30 of Set 12 | moroni
# Processing Record 31 of Set 12 | touba
# Processing Record 32 of Set 12 | marsh harbour
# Processing Record 33 of Set 12 | ust-barguzin
# Processing Record 34 of Set 12 | moranbah
# Processing Record 35 of Set 12 | harper
# Processing Record 36 of Set 12 | havelock
# Processing Record 37 of Set 12 | dudinka
# Processing Record 38 of Set 12 | shenjiamen
# Processing Record 39 of Set 12 | emba
# Processing Record 40 of Set 12 | vawkavysk
# Processing Record 41 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 12 | pasni
# Processing Record 43 of Set 12 | faya
# Processing Record 44 of Set 12 | deputatskiy
# Processing Record 45 of Set 12 | zhireken
# Processing Record 46 of Set 12 | beipiao
# Processing Record 47 of Set 12 | lingao
# Processing Record 48 of Set 12 | ayan
# Processing Record 49 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 12 | sechelt
# Processing Record 1 of Set 13 | qaqortoq
# Processing Record 2 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 3 of Set 13 | hofn
# Processing Record 4 of Set 13 | putnam
# Processing Record 5 of Set 13 | jinchang
# Processing Record 6 of Set 13 | kollumerland
# City not found. Skipping...
# Processing Record 7 of Set 13 | mrakovo
# Processing Record 8 of Set 13 | mpongwe
# Processing Record 9 of Set 13 | guozhen
# Processing Record 10 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 11 of Set 13 | ulaangom
# Processing Record 12 of Set 13 | erzin
# Processing Record 13 of Set 13 | harvard
# Processing Record 14 of Set 13 | gat
# Processing Record 15 of Set 13 | daoukro
# Processing Record 16 of Set 13 | parabel
# Processing Record 17 of Set 13 | ketchikan
# Processing Record 18 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 19 of Set 13 | bundaberg
# Processing Record 20 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 13 | mugur-aksy
# Processing Record 22 of Set 13 | itoman
# Processing Record 23 of Set 13 | katherine
# Processing Record 24 of Set 13 | vaovai
# City not found. Skipping...
# Processing Record 25 of Set 13 | nhulunbuy
# Processing Record 26 of Set 13 | anda
# Processing Record 27 of Set 13 | kingisepp
# Processing Record 28 of Set 13 | bac lieu
# Processing Record 29 of Set 13 | ludvika
# Processing Record 30 of Set 13 | birjand
# Processing Record 31 of Set 13 | gornopravdinsk
# Processing Record 32 of Set 13 | bontang
# Processing Record 33 of Set 13 | vaitape
# Processing Record 34 of Set 13 | taoudenni
# Processing Record 35 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 13 | luwuk
# Processing Record 37 of Set 13 | cairns
# Processing Record 38 of Set 13 | vuktyl
# Processing Record 39 of Set 13 | naryan-mar
# Processing Record 40 of Set 13 | banjar
# Processing Record 41 of Set 13 | lapeer
# Processing Record 42 of Set 13 | hay river
# Processing Record 43 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 13 | rabo de peixe
# Processing Record 45 of Set 13 | meiktila
# Processing Record 46 of Set 13 | fortuna
# Processing Record 47 of Set 13 | ormara
# Processing Record 48 of Set 13 | baruun-urt
# Processing Record 49 of Set 13 | santa cruz de la palma
# Processing Record 50 of Set 13 | luba
# Processing Record 1 of Set 14 | lexington
# Processing Record 2 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 3 of Set 14 | posse
# Processing Record 4 of Set 14 | souillac
# Processing Record 5 of Set 14 | korla
# Processing Record 6 of Set 14 | athens
# Processing Record 7 of Set 14 | venado tuerto
# Processing Record 8 of Set 14 | kendari
# Processing Record 9 of Set 14 | moorhead
# Processing Record 10 of Set 14 | coromandel
# Processing Record 11 of Set 14 | galveston
# Processing Record 12 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 14 | orizona
# Processing Record 14 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 14 | paignton
# Processing Record 16 of Set 14 | minsk mazowiecki
# Processing Record 17 of Set 14 | olafsvik
# Processing Record 18 of Set 14 | mumbwa
# Processing Record 19 of Set 14 | labuhan
# Processing Record 20 of Set 14 | umea
# Processing Record 21 of Set 14 | biltine
# Processing Record 22 of Set 14 | peleduy
# Processing Record 23 of Set 14 | kaduqli
# Processing Record 24 of Set 14 | verkhnetulomskiy
# Processing Record 25 of Set 14 | black river
# Processing Record 26 of Set 14 | nemuro
# Processing Record 27 of Set 14 | madang
# Processing Record 28 of Set 14 | maragogi
# Processing Record 29 of Set 14 | sucre
# Processing Record 30 of Set 14 | bud
# Processing Record 31 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 32 of Set 14 | townsville
# Processing Record 33 of Set 14 | fowa
# Processing Record 34 of Set 14 | palmer
# Processing Record 35 of Set 14 | lucea
# Processing Record 36 of Set 14 | bestobe
# Processing Record 37 of Set 14 | ballina
# Processing Record 38 of Set 14 | naze
# Processing Record 39 of Set 14 | constitucion
# Processing Record 40 of Set 14 | kolyshley
# Processing Record 41 of Set 14 | kamina
# Processing Record 42 of Set 14 | bandarbeyla
# Processing Record 43 of Set 14 | denpasar
# Processing Record 44 of Set 14 | villamontes
# Processing Record 45 of Set 14 | pryozerne
# Processing Record 46 of Set 14 | tezu
# Processing Record 47 of Set 14 | vandavasi
# Processing Record 48 of Set 14 | grand-lahou
# Processing Record 49 of Set 14 | roblin
# Processing Record 50 of Set 14 | iberia
# Processing Record 1 of Set 15 | shawnee
# Processing Record 2 of Set 15 | novovorontsovka
# Processing Record 3 of Set 15 | goundam
# Processing Record 4 of Set 15 | haines junction
# Processing Record 5 of Set 15 | teguldet
# Processing Record 6 of Set 15 | melekhovo
# Processing Record 7 of Set 15 | novi sanzhary
# Processing Record 8 of Set 15 | buraydah
# Processing Record 9 of Set 15 | raudeberg
# Processing Record 10 of Set 15 | ixtapa
# Processing Record 11 of Set 15 | magole
# Processing Record 12 of Set 15 | kotka
# Processing Record 13 of Set 15 | belogorsk
# Processing Record 14 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 15 | mayskiy
# Processing Record 16 of Set 15 | culipapa
# City not found. Skipping...
# Processing Record 17 of Set 15 | rudnaya pristan
# Processing Record 18 of Set 15 | nara
# Processing Record 19 of Set 15 | nguru
# Processing Record 20 of Set 15 | brahmapuri
# City not found. Skipping...
# Processing Record 21 of Set 15 | hambantota
# Processing Record 22 of Set 15 | seoul
# Processing Record 23 of Set 15 | almeirim
# Processing Record 24 of Set 15 | salinopolis
# Processing Record 25 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 15 | le port
# Processing Record 27 of Set 15 | paris
# Processing Record 28 of Set 15 | mkushi
# Processing Record 29 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 15 | constanza
# Processing Record 31 of Set 15 | xochihuehuetlan
# Processing Record 32 of Set 15 | moron
# Processing Record 33 of Set 15 | zhuhai
# Processing Record 34 of Set 15 | merauke
# Processing Record 35 of Set 15 | kalmunai
# Processing Record 36 of Set 15 | roma
# Processing Record 37 of Set 15 | antipino
# Processing Record 38 of Set 15 | valparaiso
# Processing Record 39 of Set 15 | leshukonskoye
# Processing Record 40 of Set 15 | madimba
# Processing Record 41 of Set 15 | samarai
# Processing Record 42 of Set 15 | abu kamal
# Processing Record 43 of Set 15 | asfi
# Processing Record 44 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 15 | malindi
# Processing Record 46 of Set 15 | general roca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data2))
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_sub_df = pd.DataFrame(city_data2)
city_data_sub_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0     Hualahuises  24.8847  -99.6733           clear sky     81.95         8
# 1        Hermanus -34.4187   19.2345          light rain     59.81        84
# 2     East London -33.0153   27.9116          few clouds     69.13        78
# 3    Ponta Do Sol  32.6667  -17.1000       broken clouds     64.06        74
# 4            Poum -20.2333  164.0167       broken clouds     78.75        78
# 5  Ribeira Grande  38.5167  -28.7000       broken clouds     61.20        88
# 6     Yellowknife  62.4560 -114.3525           clear sky      6.42        61
# 7    Punta Arenas -53.1500  -70.9167       broken clouds     55.51        50
# 8         Namwala -15.7504   26.4384       broken clouds     65.57        95
# 9            Atar  20.5169  -13.0499           clear sky     74.48        25
#
#    Cloudiness  Wind Speed Country
# 0           0        8.57      MX
# 1         100       15.17      ZA
# 2          16       16.33      ZA
# 3          56        5.12      PT
# 4          72        4.16      NC
# 5          75       24.16      PT
# 6           0       12.66      CA
# 7          75       14.97      CL
# 8          81        2.51      ZM
# 9           0        9.75      MR

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_sub_df = city_data_sub_df[new_column_order]
city_data_sub_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hualahuises      MX  24.8847  -99.6733     81.95         8           0
# 1        Hermanus      ZA -34.4187   19.2345     59.81        84         100
# 2     East London      ZA -33.0153   27.9116     69.13        78          16
# 3    Ponta Do Sol      PT  32.6667  -17.1000     64.06        74          56
# 4            Poum      NC -20.2333  164.0167     78.75        78          72
# 5  Ribeira Grande      PT  38.5167  -28.7000     61.20        88          75
# 6     Yellowknife      CA  62.4560 -114.3525      6.42        61           0
# 7    Punta Arenas      CL -53.1500  -70.9167     55.51        50          75
# 8         Namwala      ZM -15.7504   26.4384     65.57        95          81
# 9            Atar      MR  20.5169  -13.0499     74.48        25           0
#
#    Wind Speed Current Description
# 0        8.57           clear sky
# 1       15.17          light rain
# 2       16.33          few clouds
# 3        5.12       broken clouds
# 4        4.16       broken clouds
# 5       24.16       broken clouds
# 6       12.66           clear sky
# 7       14.97       broken clouds
# 8        2.51       broken clouds
# 9        9.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_sub_df.to_csv(output_data_file, index_label="City_ID")
