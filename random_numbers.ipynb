# %%
#Import the random module
import random

# %%
random.randint(-90, 90)
# Out:
# -74

# %%
random.random()
# Out:
# 0.10991987545193804

# %%
x=1
latitudes= []
while x< 11:
    random_lat= random.randint(-90,89) + random.random()
    latitudes.append(random_lat)
    x+=1
latitudes
# Out:
# [64.33975447440721,
#  64.23946941573854,
#  20.476024511685697,
#  -29.90041860411075,
#  -24.79040305752519,
#  -70.50592577690483,
#  8.467529487924473,
#  -74.5206960529315,
#  -82.44743828071421,
#  75.65604452675737]

# %%
random.randrange(-90,90, step=1)
# Out:
# -21

# %%
random.randrange(-90, 90, step=3)
# Out:
# -45

# %%
random.uniform(-90,90)
# Out:
# -70.73813374694069

# %%
#Import numpy as np
import numpy as np

# %%
np.random.uniform(-90.000,90.000)
# Out:
# -0.825406804036092

# %%
np.random.uniform(-90.000,90.000, size=50)
# Out:
# array([-74.72092157,  43.6847814 , -86.57790637,  15.06991692,
#        -74.28280462, -16.47321127,  85.0113223 ,  14.00661148,
#          5.22191143,   4.23433289, -45.38011938,  44.36870297,
#        -69.3720483 , -52.91432781,  40.69365604,  40.99085141,
#          3.36470288, -80.92934148,   5.18154883,  -1.72166304,
#        -36.67869854,  13.49270692, -89.21056841,  13.7066667 ,
#         56.37749888, -43.04416314,  -8.81116703, -72.31056639,
#         85.56595533, -65.26956821,  13.78832293,  15.12527196,
#        -59.92920914, -33.60316857, -14.59437927,  -5.79942459,
#         25.7456452 , -83.53538155, -31.17453927,  -7.1246994 ,
#        -68.46298771, -27.90723511,  80.17882286, -58.69211677,
#        -88.01505492,  78.40886983,  65.08626387,  44.63127634,
#         65.91711666,  46.26213651])

# %%
# Import timeit
import timeit

# %%
# %timeit np.random.uniform(-90.000,90.000, size=1500)
# Out:
# 11.6 µs ± 36.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes= []
    x=0
    while x < (size):
        random_lat= random.randint(-90,90) + random.random()
        latitudes.append(random_lat)
        x+= 1
    return latitudes
# Call the function with 1500
# %timeit latitudes(1500)
# Out:
# 1.12 ms ± 19.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Import the dependncies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats= np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs= np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
# Crete a practice set of random latitutude and longitude combinations
x= [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y= [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates= zip(x,y)

# %%
# Use the tuple() function to display the latitude and longitude combinations
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list
coordinates= list(lat_lngs)

# %%
# Use the citipy module to detemine city based on latitude and longitude
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]). country_code)
# Out:
# new norfolk au
# saint-philippe re
# mahebourg mu
# ribeira grande pt
# albany au
# rikitea pf
# kieta pg
# yanam in
# skage no
# mayumba ga
# qaanaaq gl
# opuwo na
# egvekinot ru
# jamestown sh
# sikasso ml
# ushuaia ar
# georgetown sh
# lebu cl
# coihaique cl
# atuona pf
# jinsha cn
# grindavik is
# longyearbyen sj
# saint-philippe re
# carnarvon au
# chokurdakh ru
# vaini to
# narsaq gl
# butaritari ki
# palabuhanratu id
# fonte boa br
# rikitea pf
# rikitea pf
# lorengau pg
# nizhneyansk ru
# araguacu br
# ribeira grande pt
# pacific grove us
# punta arenas cl
# cayenne gf
# port alfred za
# asosa et
# ushuaia ar
# hilo us
# cape town za
# busselton au
# harper lr
# hermanus za
# christchurch nz
# hobart au
# hermanus za
# vila franca do campo pt
# orumiyeh ir
# bonfim br
# barrow us
# touros br
# punta arenas cl
# kinablangan ph
# namatanai pg
# carnarvon au
# komsomolskiy ru
# morgan city us
# carnarvon au
# barentsburg sj
# ushuaia ar
# san matias bo
# road town vg
# ...

# %%
# Create a list for holding the cities
cities=[]

# Identify the nearest city for each latitude and longitude combinate
for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624
